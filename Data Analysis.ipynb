# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('November updated report 2023.csv')

# %%
df.head()
# Out:
#   CURRENT_AGENT_NAME  TICKET_ID        REQUESTER_NAME  REQUESTER_COMPANY_ID  \
# 0            BHASKAR      99466        BHASKAR PRASAD                   100
# 1            ARCHANA      99451        ARCHANA SHARMA                   100
# 2             BHARAT      99446  BHARAT BHUSHAN GUPTA                   100
# 3            ARCHANA      99439          MUKESH KUMAR                   103
# 4             BHARAT      99437  BHARAT BHUSHAN GUPTA                   100
#
#    STATUS REPORTED_ON EXPECTED_DATE RESOLVED_DATE    REQUESTER_DEPARTMENT  \
# 0  CLOSED    30-11-23      30-11-23      30-11-23  INFORMATION TECHNOLOGY
# 1  CLOSED    30-11-23           NaN      30-11-23  INFORMATION TECHNOLOGY
# 2  CLOSED    30-11-23      30-11-23      30-11-23  INFORMATION TECHNOLOGY
# 3  CLOSED    30-11-23      01-12-23      01-12-23              OPERATIONS
# 4  CLOSED    30-11-23      30-11-23      30-11-23  INFORMATION TECHNOLOGY
#
#         CATEGORY          SUB_CATEGORY AGENT_ASSIGNED_DATE  \
# ...

# %%
df
# Out:
#     CURRENT_AGENT_NAME  TICKET_ID        REQUESTER_NAME  REQUESTER_COMPANY_ID  \
# 0              BHASKAR      99466        BHASKAR PRASAD                   100
# 1              ARCHANA      99451        ARCHANA SHARMA                   100
# 2               BHARAT      99446  BHARAT BHUSHAN GUPTA                   100
# 3              ARCHANA      99439          MUKESH KUMAR                   103
# 4               BHARAT      99437  BHARAT BHUSHAN GUPTA                   100
# ..                 ...        ...                   ...                   ...
# 384         SHAILENDRA      88946      SHAILENDRA KUMAR                   100
# 385            BHASKAR      88935          SUNEEL KUMAR                   100
# 386            BHASKAR      88929       MOHAMMAD SHAMIM                   103
# 387            BHASKAR      88928          SUNEEL KUMAR                   100
# 388            BHASKAR      88922          SUNEEL KUMAR                   100
#
# ...

# %%
df.tail()
# Out:
#     CURRENT_AGENT_NAME  TICKET_ID    REQUESTER_NAME  REQUESTER_COMPANY_ID  \
# 384         SHAILENDRA      88946  SHAILENDRA KUMAR                   100
# 385            BHASKAR      88935      SUNEEL KUMAR                   100
# 386            BHASKAR      88929   MOHAMMAD SHAMIM                   103
# 387            BHASKAR      88928      SUNEEL KUMAR                   100
# 388            BHASKAR      88922      SUNEEL KUMAR                   100
#
#      STATUS REPORTED_ON EXPECTED_DATE RESOLVED_DATE    REQUESTER_DEPARTMENT  \
# 384  CLOSED    01-11-23      01-11-23      01-11-23  INFORMATION TECHNOLOGY
# 385  CLOSED    01-11-23      01-11-23      01-11-23  INFORMATION TECHNOLOGY
# 386  CLOSED    01-11-23      01-11-23      01-11-23              OPERATIONS
# 387  CLOSED    01-11-23      01-11-23      01-11-23  INFORMATION TECHNOLOGY
# 388  CLOSED    01-11-23      01-11-23      01-11-23  INFORMATION TECHNOLOGY
#
#           CATEGORY          SUB_CATEGORY AGENT_ASSIGNED_DATE  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CURRENT_AGENT_NAME           389 non-null    object
#  1   TICKET_ID                    389 non-null    int64
#  2   REQUESTER_NAME               389 non-null    object
#  3   REQUESTER_COMPANY_ID         389 non-null    int64
#  4   STATUS                       389 non-null    object
#  5   REPORTED_ON                  389 non-null    object
#  6   EXPECTED_DATE                384 non-null    object
#  7   RESOLVED_DATE                388 non-null    object
#  8   REQUESTER_DEPARTMENT         389 non-null    object
#  9   CATEGORY                     388 non-null    object
#  10  SUB_CATEGORY                 388 non-null    object
#  11  AGENT_ASSIGNED_DATE          389 non-null    object
#  12  SUBJECT                      389 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# CURRENT_AGENT_NAME               0
# TICKET_ID                        0
# REQUESTER_NAME                   0
# REQUESTER_COMPANY_ID             0
# STATUS                           0
# REPORTED_ON                      0
# EXPECTED_DATE                    5
# RESOLVED_DATE                    1
# REQUESTER_DEPARTMENT             0
# CATEGORY                         1
# SUB_CATEGORY                     1
# AGENT_ASSIGNED_DATE              0
# SUBJECT                          0
# REQUESTER_LOCATION               0
# INITIAL_RESPONSE (IN HOURS)    301
# CLOSING_TIME(IN MINUTES)         2
# REQUEST_DAY                      0
# GROUP_DEPARTMENT_NAME          389
# REMARKS                         59
# CLOSED_BY                        0
# dtype: int64

# %%
df.shape
# Out:
# (389, 20)

# %%
df.columns
# Out:
# Index(['CURRENT_AGENT_NAME', 'TICKET_ID', 'REQUESTER_NAME',
#        'REQUESTER_COMPANY_ID', 'STATUS', 'REPORTED_ON', 'EXPECTED_DATE',
#        'RESOLVED_DATE', 'REQUESTER_DEPARTMENT', 'CATEGORY', 'SUB_CATEGORY',
#        'AGENT_ASSIGNED_DATE', 'SUBJECT', 'REQUESTER_LOCATION',
#        'INITIAL_RESPONSE (IN HOURS)', 'CLOSING_TIME(IN MINUTES)',
#        'REQUEST_DAY', 'GROUP_DEPARTMENT_NAME', 'REMARKS', 'CLOSED_BY'],
#       dtype='object')

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df['REQUESTER_COMPANY_ID'].nunique(),df['STATUS'].nunique(),df['REQUESTER_DEPARTMENT'].nunique()
# Out:
# (4, 2, 16)

# %%
df['CURRENT_AGENT_NAME'].nunique()
# Out:
# 7

# %%
df['REPORTED_ON'].values
# Out:
# array(['30-11-23', '30-11-23', '30-11-23', '30-11-23', '30-11-23',
#        '30-11-23', '30-11-23', '30-11-23', '30-11-23', '30-11-23',
#        '30-11-23', '30-11-23', '30-11-23', '30-11-23', '30-11-23',
#        '30-11-23', '30-11-23', '30-11-23', '30-11-23', '30-11-23',
#        '29-11-23', '29-11-23', '29-11-23', '29-11-23', '29-11-23',
#        '29-11-23', '29-11-23', '29-11-23', '29-11-23', '29-11-23',
#        '29-11-23', '29-11-23', '29-11-23', '29-11-23', '29-11-23',
#        '29-11-23', '29-11-23', '29-11-23', '28-11-23', '28-11-23',
#        '28-11-23', '28-11-23', '28-11-23', '28-11-23', '28-11-23',
#        '28-11-23', '28-11-23', '28-11-23', '28-11-23', '28-11-23',
#        '28-11-23', '28-11-23', '28-11-23', '28-11-23', '28-11-23',
#        '27-11-23', '26-11-23', '26-11-23', '25-11-23', '25-11-23',
#        '25-11-23', '24-11-23', '24-11-23', '24-11-23', '24-11-23',
#        '24-11-23', '24-11-23', '24-11-23', '24-11-23', '24-11-23',
# ...

# %%
df[ 'TICKET_ID'].nunique()
# Out:
# 389

# %%
plt.figure(figsize=(13, 15))

plt.subplot(211)
sns.countplot(hue='CLOSED_BY',x='CURRENT_AGENT_NAME', data=df)
# Out:
# <Axes: xlabel='CURRENT_AGENT_NAME', ylabel='count'>

# %%
plt.figure(figsize=(15, 10))

plt.subplot(211)
sns.countplot(x='CLOSED_BY', hue='REQUEST_DAY', data=df)
# Out:
# <Axes: xlabel='CLOSED_BY', ylabel='count'>

# %%
plt.figure(figsize=(10, 15))

plt.subplot(311)
sns.countplot(x='CURRENT_AGENT_NAME',hue='REQUESTER_COMPANY_ID',data=df)
plt.title('HANDLE DIFFERENT COMPANIES TICKETS')
# Out:
# Text(0.5, 1.0, 'HANDLE DIFFERENT COMPANIES TICKETS')
